# %% [markdown]
# # Udemy Course: Python A-Z
# ## Section 6 - Advanced Visualization
#
# Python Programming A-Z™
#
# © Kirill Eremenko
#
# [Super Data Science](http://www.superdatascience.com)

# %%
#Jupyter notebook notes
# to get a delimiter line 
#1. Turn cell to markdown => esc + M
#2. Then type ---
#to execute => SHIFT + ENTER

# %% [markdown]
# ---
# **Category data type**

# %%
#let's import all our packages
import pandas as pd
import numpy as np
import os

#plotting packages
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
os.getcwd()
# Out:
# '/Users/yinka_ola/Google Drive/_Udemy/Phython A-Z/Section 6'

# %%
os.chdir('/Users/yinka_ola/Google Drive/_Udemy/Phython A-Z/Section 6')
os.getcwd()
# Out:
# '/Users/yinka_ola/Google Drive/_Udemy/Phython A-Z/Section 6'

# %%
movies = pd.read_csv("P4-Movie-Ratings.csv")

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
#let's explore/check the data
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
#spaces can be inconvenient when accessing cells -> remove them
movies.columns = [ 'Film', 'Genre', 'CriticRating', 'AudienceRating',
       'BudgetMillion', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
#let's get some info  about our dataset
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null object
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillion     559 non-null int64
# Year              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
#let's get some stats around our dataset
#these number does not make sense for year ( what is the average of year?)
#year is a category, not a number
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillion         Year
# count    559.000000      559.000000     559.000000   559.000000
# mean      47.309481       58.744186      50.236136  2009.152057
# std       26.413091       16.826887      48.731817     1.362632
# min        0.000000        0.000000       0.000000  2007.000000
# 25%       25.000000       47.000000      20.000000  2008.000000
# 50%       46.000000       58.000000      35.000000  2009.000000
# 75%       70.000000       72.000000      65.000000  2010.000000
# max       97.000000       96.000000     300.000000  2011.000000

# %%
movies.Film
# Out:
# 0                   (500) Days of Summer
# 1                             10,000 B.C.
# 2                              12 Rounds
# 3                               127 Hours
# 4                               17 Again
# 5                                    2012
# 6                              27 Dresses
# 7                        30 Days of Night
# 8                      30 Minutes or Less
# 9                                   50/50
# 10                             88 Minutes
# 11                     A Dangerous Method
# 12              A Nightmare on Elm Street
# 13                         A Serious Man
# 14      A Very Harold and Kumar Christmas
# 15                              Abduction
# 16                    Across the Universe
# 17                         Adventureland
# 18                           Albert Nobbs
# 19                    Alice in Wonderland
# 20          Alien vs. Predator -- Requiem
# 21                   Aliens in the Attic
# ...

# %%
#let's change the datatype of the dataset
movies.Film = movies.Film.astype('category')

# %%
# Film is now a category
#IN R: Factor = Category
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillion     559 non-null int64
# Year              559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
#convert Genre and Year column into category
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
#let's check
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillion     559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
# now let's check the stats
#here just the number type s created
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillion
# count    559.000000      559.000000     559.000000
# mean      47.309481       58.744186      50.236136
# std       26.413091       16.826887      48.731817
# min        0.000000        0.000000       0.000000
# 25%       25.000000       47.000000      20.000000
# 50%       46.000000       58.000000      35.000000
# 75%       70.000000       72.000000      65.000000
# max       97.000000       96.000000     300.000000

# %% [markdown]
# ---
# **JointPlots**

# %%
#let's import all required packages to be used
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#JoinPlots
#investigate the relationship between CriticRating and AudienceRating
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating')

# %%
# you can also change the style of the visualization
#jupiter has very useful information by clickin 'shift + tab'
#let's change from scatter plot

j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating', kind='hex')

#by using the hex, it allows you to view the clusters and they are associated with the distribution graph
#seaborn and python creates

# %% [markdown]
# ---
# **Histograms**

# %%
#we already know this method:
ml = sns.distplot(movies.AudienceRating, bins=30)

# %%
#critic rating
ml2 = sns.distplot(movies.CriticRating, bins=30)

# %%
#let's super impose the graph
ml = sns.distplot(movies.AudienceRating, bins=30)
ml2 = sns.distplot(movies.CriticRating, bins=30)

#it looks like critic rating has some rule behind it, which is why the critic plot is not normally distributed 
#as there are criteria that they follow
#when something is 'natural' or emotional such as audience rating, you get a normal distribution

# %%
#seaborn is an addon on top of pyplot
#it adds the probability density function
#without seaborn:
sns.set_style("white")
n1 = plt.hist(movies.AudienceRating, bins=15)

# %%
sns.set_style("darkgrid")
n1 = plt.hist(movies.AudienceRating, bins=15)

# %%
#let's super impose the plot
sns.set_style("darkgrid")
n1 = plt.hist(movies.AudienceRating, bins=15) #blue
n2 = plt.hist(movies.CriticRating, bins=15) #orange

# %% [markdown]
# ---
# **Stacked Histograms in Python**

# %%
#let's investigate the budget
h1 = plt.hist(movies.BudgetMillion)

# %%
#let's investigate the budget for a certain genre
movies[movies.Genre =='Drama'].BudgetMillion
plt.hist(movies[movies.Genre =='Drama'].BudgetMillion, bins=15)
plt.show()

# %%
#let's look at a collection of categories
plt.hist(movies[movies.Genre =='Drama'].BudgetMillion, bins=15)
plt.hist(movies[movies.Genre =='Action'].BudgetMillion , bins=15)
plt.hist(movies[movies.Genre =='Thriller'].BudgetMillion, bins=15)
plt.show()

# %%
#we want our visualizations to stack instead of overlay
#input them in a list

plt.hist([movies[movies.Genre =='Drama'].BudgetMillion,
          movies[movies.Genre =='Action'].BudgetMillion], 
          bins=15, stacked=True)
plt.show()

#the above is a repetitive task and can be placed in a loop and iterated

# %%
#let's take a look at the categories under Genre
gen = movies.Genre.cat.categories
gen
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
#let's create a loop
for gen in movies.Genre.cat.categories:
    print (gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
#we want the lop to create the list for us
#first create an empty list

list1 = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillion) 
plt.show()

print(list1)
# Out:
# [2       20
# 5      200
# 15      35
# 29      20
# 30      20
# 33     237
# 36      45
# 39      45
# 40      70
# 45     150
# 49      68
# 52      17
# 58     140
# 60      85
# 63      40
# 66     125
# 67      25
# 69      40
# 70      90
# 73      30
# 76     163
# 77      13
# 81      25
# 83      20
# 86      45
# 94      30
# 98      33
# 101     75
# 102     30
# 106     45
#       ...
# 433    138
# 435     50
# 439     40
# 441     80
# 443    150
# 448     25
# 451     40
# 454    145
# 458    100
# 472    150
# 473      6
# 474      0
# 477    100
# 479     75
# 493    150
# 495     35
# 499    150
# 500    195
# 501    210
# 502     30
# 504    170
# 512     35
# 514     95
# 528     75
# 530     25
# 531    130
# 542     35
# 546    150
# 547    160
# 557     24
# Name: BudgetMillion, Length: 154, dtype: int64, 1      105
# 3       18
# 19     200
# 21      45
# 24      40
# 32      78
# 46      20
# 65      38
# 68     140
# 130     73
# 165     12
# 166    125
# ...

# %%
# let's plot our new plot

list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillion) 
    mylabels.append(gen)

h = plt.hist(list1, bins=30, stacked=True, rwidth=1, label= mylabels)
plt.legend() #add a legend
plt.show()

#let's add a label

# %% [markdown]
# ---
# **Kernel Density Estimate (KDE) Plot**

# %%
vis1= sns.lmplot(data=movies, x='CriticRating', y='AudienceRating', 
                 fit_reg=False, hue='Genre', size =7, aspect=1)

# %%
#KDE Plot
#this gives us a quick density estimate
k1= sns.kdeplot(movies.CriticRating, movies.AudienceRating)

# %%
#let's add some more colours
k1= sns.kdeplot(movies.CriticRating, movies.AudienceRating,
                 shade=True, shade_lowest=False)

# %%
#change the colour
k1= sns.kdeplot(movies.CriticRating, movies.AudienceRating,
                 shade=True, shade_lowest=False, cmap='Reds')

# %%
#now overlay the plot
#change the colour and smooth it out
k1= sns.kdeplot(movies.CriticRating, movies.AudienceRating,
                 shade=True, shade_lowest=False, cmap='Reds')
#Tip to smoothen out the plot
k1b= sns.kdeplot(movies.CriticRating, movies.AudienceRating,
                  cmap='Reds')

# %% [markdown]
# ---
# **Working with Subplots()**

# %%
#it allows for advance level plotting in python
import seaborn as sns
sns.set()

# %%
#remove the grid
sns.set_style("dark")
k1 = sns.kdeplot(movies.BudgetMillion, movies.AudienceRating)

# %%
#compare the critic rating to the film budget
#you can continur to slice it
sns.set_style("dark")
k2 = sns.kdeplot(movies.BudgetMillion, movies.CriticRating)

# %%
sns.set_style("dark")
k2= sns.kdeplot(movies.BudgetMillion, movies.CriticRating,
                  cmap='Blues')

# %%
#Subplots

f, ax = plt.subplots (1,2, figsize=(12,6))

# %%
#now let's put our plots side by side
#ax: single axis object or either an array of axes
f, axes = plt.subplots (1,2, figsize=(12,6))
k1 = sns.kdeplot(movies.BudgetMillion, movies.AudienceRating, ax=axes[0])
k2 = sns.kdeplot(movies.BudgetMillion, movies.CriticRating, ax=axes[1])

# %%
#here you are plotting a 2D array
#you have to specify the array n the axes
f, axes = plt.subplots (2,2, figsize=(12,6))
k1 = sns.kdeplot(movies.BudgetMillion, movies.AudienceRating, ax=axes[1,1])
k2 = sns.kdeplot(movies.BudgetMillion, movies.CriticRating, ax=axes[1,0])

# %%
#lets make our chart prettier
#now let's put our plots side by side
#ax: single axis object or either an array of axes
f, axes = plt.subplots (1,2, figsize=(12,6), sharex=True, sharey=True)
k1 = sns.kdeplot(movies.BudgetMillion, movies.AudienceRating, ax=axes[0])
k2 = sns.kdeplot(movies.BudgetMillion, movies.CriticRating, ax=axes[1])
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %% [markdown]
# ---
# **Violinplots vs Boxplots**

# %%
#Violinplots
w = sns.violinplot(data=movies, x='Genre', y='CriticRating')

# %%
#Boxplots
w = sns.boxplot(data=movies, x='Genre', y='CriticRating')
#assuming you create a movie with average criteria, then it is better to create a thriller, rather than a horror movie

# %%
#sometimes, violinplot can show us more information
w = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %% [markdown]
# ---
# **Facet Grid**

# %%
#this chart is too cumbersome to  garner insight from the data
#let's use a facet to simplify the grid
vis1= sns.lmplot(data=movies, x='CriticRating', y='AudienceRating', 
                 fit_reg=False, hue='Genre', size =7, aspect=1)

# %%
#Facet Grid
#concept is similar to subplots
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')

# %%
#let's map onto the facet grid
#g = g.map()

#scatterplot
##plot.scatter(movies.CriticRating, movies.AudienceRating)
#now pass this function into g.map()
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g = g.map (plt.scatter, 'CriticRating', 'AudienceRating')

# %%
#note that you can populate a facet with any chart type

#histogram
#scatterplot

g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g = g.map (plt.hist, 'BudgetMillion')

# %%
#back to scatterplot:

#scatterplot
##plot.scatter(movies.CriticRating, movies.AudienceRating)
#now pass this function into g.map()
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map (plt.scatter, 'CriticRating', 'AudienceRating', **kws)

#here we are analyzing overtime (left to right)

# %% [markdown]
# ---
# **Coordinates and Diagonals**

# %%
#first set limit to the axes
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map (plt.scatter, 'CriticRating', 'AudienceRating', **kws)
g.set(xlim=(0,100), ylim=(0,100))

# %%
#Chart #5
#iteration over the array
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map (plt.scatter, 'CriticRating', 'AudienceRating', **kws)
g.set(xlim=(0,100), ylim=(0,100))

for ax in g.axes.flat:
    ax.plot((0,100), (0,100), c="gray", ls="--")
g.add_legend() 
plt.show()


#here the line helps better with the visualization of the data
#if over the line => better ratings

# %% [markdown]
# ---
# **Building Dashboards in Python**

# %%
# A dashboard is a combination of charts
#we will use the subplots function to create a dashboard
#recall plotting packages

from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style("darkgrid")
f, axes = plt.subplots(2,2, figsize=(15,15))
k1 = sns.kdeplot(movies.BudgetMillion, movies.AudienceRating, ax=axes[0,0])
k2 = sns.kdeplot(movies.BudgetMillion, movies.CriticRating, ax=axes[0,1])


#Violinplots
w1 = sns.violinplot(data=movies, x='Genre', y='CriticRating', ax=axes[1,0])

#KDE plot
k4= sns.kdeplot(movies.CriticRating, movies.AudienceRating,
                 shade=True, shade_lowest=False, cmap='Reds', ax=axes[1,1])
#Tip t smoothen out the plot
k4b= sns.kdeplot(movies.CriticRating, movies.AudienceRating,
                  cmap='Reds', ax=axes[1,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
k4.set(xlim=(-20,160))
k4b.set(xlim=(-20,160))

plt.show()

# %%
#note: axes is a pyplot object
#seaborn comes on top of pyplot, so there are some parameter that do not have visibility  into seaborn
#keep this in mind for the axes
#pyplot don't have visibility of seaborn object

# %% [markdown]
# ---
# **Styling Dashboards Tips**

# %%
sns.set_style("darkgrid") #white whitegrid, dark
f, axes = plt.subplots(2,2, figsize=(15,15))

#Plot [0,0]
k1 = sns.kdeplot(movies.BudgetMillion, movies.AudienceRating,
                 shade=True, shade_lowest=True, cmap='Greens', ax=axes[0,0])
k1b = sns.kdeplot(movies.BudgetMillion, movies.AudienceRating,
                 shade=True, shade_lowest=True, cmap='Greens', ax=axes[0,0])

#Plot [0,1]
k2 = sns.kdeplot(movies.BudgetMillion, movies.CriticRating,
                 shade=True, shade_lowest=True, cmap='inferno',ax=axes[0,1])

k2b = sns.kdeplot(movies.BudgetMillion, movies.CriticRating,
                 shade=True, shade_lowest=True, cmap='Blues',ax=axes[0,1])


#Plot [1,0]
#Violinplots
w1 = sns.violinplot(data=movies, x='Genre', y='CriticRating', 
                    palette ='cool', ax=axes[1,0]) #using palette

#Plot [1,1]
#KDE plot
k4= sns.kdeplot(movies.CriticRating, movies.AudienceRating,
                 shade=True, shade_lowest=False, cmap='Reds', ax=axes[1,1])

k4b= sns.kdeplot(movies.CriticRating, movies.AudienceRating,
                  cmap='Reds', ax=axes[1,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
k4.set(xlim=(-20,160))
k4b.set(xlim=(-20,160))

plt.show()

# %% [markdown]
# ---
# **Finishing Touches on Dashboards**

# %%
#Thematic Edits
#how do we improve the chart visually?

#let's plot our new plot
list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillion) 
    mylabels.append(gen)

sns.set_style("whitegrid") #it affects styles of non visualization
#create a subplot with just 1 item

fig, ax = plt.subplots()
fig.set_size_inches (11, 8) # size of A4 paper

h = plt.hist(list1, bins=30, stacked=True, rwidth=1, label= mylabels)
plt.title("Movie Budget Distribution", fontsize=25, color ="DarkBlue", fontname="Console")
plt.ylabel("Number of Movies", fontsize=25, color="Red")
plt.xlabel("Budget", fontsize=25, color="Green")

plt.yticks(fontsize=20)
plt.xticks(fontsize=20)

plt.legend(frameon=True, fancybox=True, shadow=True, 
           framealpha=1,prop={'size':20}) #add a legend
plt.show()
